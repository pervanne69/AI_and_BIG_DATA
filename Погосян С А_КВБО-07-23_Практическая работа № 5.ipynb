# %%
import math

class Trigonometry:
    @staticmethod
    def cos(angle_rad: float) -> float:
        """Вычисление косинуса угла в радианах."""
        return math.cos(angle_rad)
    
    @staticmethod
    def sin(angle_rad: float) -> float:
        """Вычисление синуса угла в радианах."""
        return math.sin(angle_rad)
    
    @staticmethod
    def tan(angle_rad: float) -> float:
        """Вычисление тангенса угла в радианах."""
        return math.tan(angle_rad)
    
    @staticmethod
    def arcsin(value: float) -> float:
        """Вычисление арксинуса значения (возвращает угол в радианах)."""
        if -1 <= value <= 1:
            return math.asin(value)
        else:
            raise ValueError("Значение должно быть в диапазоне от -1 до 1.")
    
    @staticmethod
    def arccos(value: float) -> float:
        """Вычисление арккосинуса значения (возвращает угол в радианах)."""
        if -1 <= value <= 1:
            return math.acos(value)
        else:
            raise ValueError("Значение должно быть в диапазоне от -1 до 1.")
    
    @staticmethod
    def arctan(value: float) -> float:
        """Вычисление арктангенса значения (возвращает угол в радианах)."""
        return math.atan(value)
    
    @staticmethod
    def degrees_to_radians(degrees: float) -> float:
        """Перевод угла из градусов в радианы."""
        return math.radians(degrees)

# Пример использования:
angle_in_degrees = 45
angle_in_radians = Trigonometry.degrees_to_radians(angle_in_degrees)

print("Косинус:", Trigonometry.cos(angle_in_radians))
print("Синус:", Trigonometry.sin(angle_in_radians))
print("Тангенс:", Trigonometry.tan(angle_in_radians))
# Out:
# Косинус: 0.7071067811865476
# Синус: 0.7071067811865476
# Тангенс: 0.9999999999999999

# %%
tree = ['a', 
        ['b', 
            ['d', [], []], 
            ['e', [], []]
        ], 
        ['c', 
            [], 
            ['f', [], []]
        ]
       ]

# Печать корня, левого и правого поддеревьев
print("Корень дерева:", tree[0])
print("Левое поддерево корня:", tree[1])
print("Правое поддерево корня:", tree[2])
# Out:
# Корень дерева: a
# Левое поддерево корня: ['b', ['d', [], []], ['e', [], []]]
# Правое поддерево корня: ['c', [], ['f', [], []]]

# %%
import random

class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
        
    def insert(self, value):
        if value < self.data:
            if self.left is None:
                self.left = Tree(value)
            else:
                self.left.insert(value)
        elif value > self.data:
            if self.right is None:
                self.right = Tree(value)
            else:
                self.right.insert(value)
        else:
            pass
    def print_tree(self, level=0, label="Root"):
        print("    " * level + f"{label}: {self.data}")
        if self.right:
            self.right.print_tree(level + 1, "Right")
        if self.left:
            self.left.print_tree(level + 1, "Left")
            
            
tree = Tree(10)
for i in range(20):
    tree.insert(random.randint(1, 100))
tree.print_tree()
# Out:
# Root: 10
#     Right: 64
#         Right: 68
#             Right: 81
#                 Right: 89
#                     Left: 85
#                 Left: 80
#             Left: 67
#         Left: 43
#             Right: 46
#                 Right: 57
#             Left: 15
#                 Right: 28
#                     Right: 40
#                         Left: 29
#                     Left: 27
#     Left: 1
#         Right: 5
#             Right: 8

# %%
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
x = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
target = [0, 0, 0, 1, 1, 1]

x_train, x_test, y_train, y_test = train_test_split(x, target, test_size=0.2)

print(x_train, x_test, y_train, y_test, sep="\n")
# Out:
# [[ 1  1]
#  [ 2  1]
#  [ 3  2]
#  [-1 -1]]
# [[-2 -1]
#  [-3 -2]]
# [1, 1, 1, 0]
# [0, 0]

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.625, 0.5, '  False')]

# %%
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([1, 1])

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[2]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# C:\Users\samve\PycharmProjects\Практики по большим данным\.venv\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor



dataframe = pd.read_csv("petrol_consumption.csv")
dataframe = dataframe[['Petrol_Consumption', 'Petrol_tax', 
'Average_income']]
print("Dataframe first 5 lines:", dataframe.head(5), sep="\n")
print("Dataframe description: ", dataframe.describe(), sep="\n")
print("Dataframe shape: ", dataframe.shape)


x = dataframe[["Average_income", "Petrol_tax"]]
y = dataframe["Petrol_Consumption"]
# Out:
# Dataframe first 5 lines:
#    Petrol_Consumption  Petrol_tax  Average_income
# 0                 541         9.0            3571
# 1                 524         9.0            4092
# 2                 561         9.0            3865
# 3                 414         7.5            4870
# 4                 410         8.0            4399
# Dataframe description:
#        Petrol_Consumption  Petrol_tax  Average_income
# count           48.000000   48.000000       48.000000
# mean           576.770833    7.668333     4241.833333
# std            111.885816    0.950770      573.623768
# min            344.000000    5.000000     3063.000000
# 25%            509.500000    7.000000     3739.000000
# 50%            568.500000    7.500000     4298.000000
# 75%            632.750000    8.125000     4578.750000
# max            968.000000   10.000000     5342.000000
# Dataframe shape:  (48, 3)

# %%
 
x_train, x_test, y_train, y_test = train_test_split(x, y, 
test_size=0.2, random_state=0)
print("Набор стажа для обучения: ", x_train, 
  "Набор стажа для тестирования:", x_test, 
  "Набор зарплат для обучения:", y_train, 
  "Набор зарплат для тестирования:", y_test, sep="\n")
# Out:
# Набор стажа для обучения:
#     Average_income  Petrol_tax
# 11            5126        7.50
# 31            3333        7.00
# 33            3357        7.50
# 27            3846        7.50
# 47            5002        7.00
# 2             3865        9.00
# 46            4296        7.00
# 18            4716        7.00
# 15            4318        7.00
# 28            4188        8.00
# 22            4897        9.00
# 16            4206        7.00
# 41            3656        7.00
# 20            4593        7.00
# 42            4300        7.00
# 8             4447        8.00
# 13            4207        7.00
# 25            3721        9.00
# 5             5342       10.00
# 17            3718        7.00
# 35            3802        6.58
# 14            4332        7.00
# 38            3635        8.50
# 1             4092        9.00
# 12            4817        7.00
# 43            3745        7.00
# 24            4574        8.50
# 6             5319        8.00
# ...

# %%
regressor = DecisionTreeRegressor()
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn import tree
tree.plot_tree(regressor)
# Out:
# [Text(0.4975, 0.9375, 'x[1] <= 7.25\nsquared_error = 13692.341\nsamples = 38\nvalue = 583.974'),
#  Text(0.23, 0.8125, 'x[0] <= 4338.5\nsquared_error = 14168.986\nsamples = 19\nvalue = 642.474'),
#  Text(0.36375, 0.875, 'True  '),
#  Text(0.14, 0.6875, 'x[0] <= 4125.5\nsquared_error = 3108.889\nsamples = 12\nvalue = 616.333'),
#  Text(0.06, 0.5625, 'x[0] <= 3494.5\nsquared_error = 3128.222\nsamples = 6\nvalue = 640.333'),
#  Text(0.04, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 554.0'),
#  Text(0.08, 0.4375, 'x[0] <= 3731.5\nsquared_error = 1965.04\nsamples = 5\nvalue = 657.6'),
#  Text(0.04, 0.3125, 'x[0] <= 3687.0\nsquared_error = 56.25\nsamples = 2\nvalue = 706.5'),
#  Text(0.02, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 699.0'),
#  Text(0.06, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 714.0'),
#  Text(0.12, 0.3125, 'x[1] <= 6.79\nsquared_error = 580.667\nsamples = 3\nvalue = 625.0'),
# ...

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([541., 464., 574., 699., 574., 591., 574., 498., 540., 574.])

# %%
df = pd.DataFrame({"Actual": y_test, "Predicted": y_pred})
df
# Out:
#     Actual  Predicted
# 29     534      541.0
# 4      410      464.0
# 26     577      574.0
# 30     571      699.0
# 32     577      574.0
# 37     704      591.0
# 34     487      574.0
# 40     587      498.0
# 7      467      540.0
# 10     580      574.0

# %%
from sklearn import metrics
import numpy as np
print("Mean Squared Error: ", metrics.mean_squared_error(y_test, y_pred))
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error:  5299.1
# Mean Absolute Error:  56.3

# %%
float(metrics.mean_absolute_error(y_test, y_pred) / np.average(y) * 100)
# Out:
# 9.761242550117391
